# %% [markdown]
# <a href="https://colab.research.google.com/github/hitanshu5/MachineLearning/blob/main/FeatureImportance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
from sklearn.datasets import load_iris

# %%
dataset = load_iris()

df=pd.DataFrame(dataset.data)
df.columns=dataset.feature_names

df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
df['Species'] = dataset.target

df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    Species
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0

# %%
df['Species'].unique()
# Out:
# array([0, 1, 2])

# %%
X = df[['sepal length (cm)','sepal width (cm)','petal length (cm)','petal width (cm)']]
y = df['Species']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3)

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier()
rfc.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
imp = rfc.feature_importances_
imp
# Out:
# array([0.07941281, 0.02786048, 0.44788975, 0.44483697])

# %%
feat_names = list(X_train.columns)
indices = np.argsort(imp)[::-1]

plt.bar(range(X_train.shape[1]),imp[indices])
plt.xticks(range(X_train.shape[1]),feat_names, rotation=90)
plt.show()
